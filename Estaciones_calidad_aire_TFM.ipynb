# %% [markdown]
# <img  src="data:image/png;base64,...">
#
#
#  #                                           Datos Estaciones Calidad del Aire Municipio de Madrid

# %% [markdown]
# ### Autor: Alicia Ruiz Moreno

# %%
import pandas as pd

# %%
data = pd.read_csv('informacion_estaciones_red_calidad_aire.csv', encoding='latin-1', sep=';')

# %%
data
# Out:
#     ï»¿CODIGO  CODIGO_CORTO              ESTACION  \
# 0    28079004             4      Plaza de EspaÃ±a
# 1    28079008             8      Escuelas Aguirre
# 2    28079011            11        RamÃ³n y Cajal
# 3    28079016            16          Arturo Soria
# 4    28079017            17            Villaverde
# 5    28079018            18             Farolillo
# 6    28079024            24         Casa de Campo
# 7    28079027            27        Barajas Pueblo
# 8    28079035            35      Plaza del Carmen
# 9    28079036            36             Moratalaz
# 10   28079038            38        Cuatro Caminos
# 11   28079039            39      Barrio del Pilar
# 12   28079040            40              Vallecas
# 13   28079047            47       MÃ©ndez Ãlvaro
# 14   28079048            48            Castellana
# 15   28079049            49     Parque del Retiro
# 16   28079050            50        Plaza Castilla
# 17   28079054            54  Ensanche de Vallecas
# ...

# %%
df = pd.DataFrame(data)

# %%
import unicodedata

# %%
def corregir_caracteres_especiales(df, columna):
    df[columna] = df[columna].apply(lambda x: unicodedata.normalize('NFKD', str(x)).encode('ASCII', 'ignore').decode('ASCII'))
    
    return(df)

# %%
corregir_caracteres_especiales(df, 'VIA_NOMBRE')
# Out:
#     ï»¿CODIGO  CODIGO_CORTO              ESTACION  \
# 0    28079004             4       Plaza de EspaAa
# 1    28079008             8      Escuelas Aguirre
# 2    28079011            11        RamA3n y Cajal
# 3    28079016            16          Arturo Soria
# 4    28079017            17            Villaverde
# 5    28079018            18             Farolillo
# 6    28079024            24         Casa de Campo
# 7    28079027            27        Barajas Pueblo
# 8    28079035            35      Plaza del Carmen
# 9    28079036            36             Moratalaz
# 10   28079038            38        Cuatro Caminos
# 11   28079039            39      Barrio del Pilar
# 12   28079040            40              Vallecas
# 13   28079047            47         MAndez Alvaro
# 14   28079048            48            Castellana
# 15   28079049            49     Parque del Retiro
# 16   28079050            50        Plaza Castilla
# 17   28079054            54  Ensanche de Vallecas
# ...

# %%
df3.columns
# Out:
# Index(['ï»¿CODIGO', 'CODIGO_CORTO', 'ESTACION', 'DIRECCION', 'LONGITUD_ETRS89',
#        'LATITUD_ETRS89', 'ALTITUD', 'COD_TIPO', 'NOM_TIPO', 'NO2', 'SO2', 'CO',
#        'PM10', 'PM2_5', 'O3', 'BTX', 'COD_VIA', 'VIA_CLASE', 'VIA_PAR',
#        'VIA_NOMBRE', 'Fecha alta', 'COORDENADA_X_ETRS89',
#        'COORDENADA_Y_ETRS89', 'LONGITUD', 'LATITUD'],
#       dtype='object')

# %%
df3['CODIGO_CORTO'].unique()
# Out:
# array([ 4,  8, 11, 16, 17, 18, 24, 27, 35, 36, 38, 39, 40, 47, 48, 49, 50,
#        54, 55, 56, 57, 58, 59, 60])

# %%
df3['ï»¿CODIGO'].unique()
# Out:
# array([28079004, 28079008, 28079011, 28079016, 28079017, 28079018,
#        28079024, 28079027, 28079035, 28079036, 28079038, 28079039,
#        28079040, 28079047, 28079048, 28079049, 28079050, 28079054,
#        28079055, 28079056, 28079057, 28079058, 28079059, 28079060])
