# %%
import pandas as pd

# %%
data = pd.read_csv('Estaciones_control_datos_meteorologicos (1).csv', encoding='latin-1', sep=';')

# %%
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#     ï»¿CÃDIGO  CÃDIGO_CORTO                  ESTACIÃN  \
# 0     28079004              4              Plaza EspaÃ±a
# 1     28079008              8           Escuelas Aguirre
# 2     28079016             16               Arturo Soria
# 3     28079018             18                  Farolillo
# 4     28079024             24              Casa de Campo
# 5     28079035             35           Plaza del Carmen
# 6     28079036             36                  Moratalaz
# 7     28079038             38             Cuatro Caminos
# 8     28079039             39           Barrio del Pilar
# 9     28079054             54       Ensanche de Vallecas
# 10    28079056             56            Plaza ElÃ­ptica
# 11    28079058             58                   El Pardo
# 12    28079059             59              Juan Carlos I
# 13    28079102            102           J.M.D. Moratalaz
# 14    28079103            103          J.M.D. Villaverde
# ...

# %%
df1.columns
# Out:
# Index(['ï»¿CÃDIGO', 'CÃDIGO_CORTO', 'ESTACIÃN', 'DIRECCION',
#        'LONGITUD_ETRS89', 'LATITUD_ETRS89', 'ALTITUD', 'VV (81)', 'DV (82)',
#        'T (83)', 'HR (86)', 'PB (87)', 'RS (88)', 'P (89)', 'COD_VIA',
#        'VIA_CLASE', 'VIA_PAR', 'VIA_NOMBRE', 'NUM_VIA', 'COORDENADA_X_ETRS89',
#        'COORDENADA_Y_ETRS89', 'LONGITUD', 'LATITUD'],
#       dtype='object')
