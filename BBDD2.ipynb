# %%
import pandas as pd
import math

# %%
data = pd.read_csv('tabla_combinada.csv', encoding='latin-1', sep=',')

# %%
df = pd.DataFrame(data)

# %%
df.isnull().sum()
# Out:
# estacion        0
# Datetime        0
# DV          14694
# HR           3051
# P           13035
# PB          16329
# RS          16254
# RU           4266
# TEMP         2236
# VV          14667
# BEN         14740
# CH4          7893
# CO          10954
# EBE         14802
# NMHC         7893
# NO             77
# NO2            77
# NOX            77
# O3           5783
# PM10        11577
# PM25        14761
# SO2         12849
# TCH          7893
# TOL         14756
# dtype: int64

# %%
df.describe()
# Out:
#            estacion           DV            HR            P           PB  \
# count  21187.000000  6493.000000  18136.000000  8152.000000  4858.000000
# mean      34.755463    98.428769     56.689843     0.918885   944.964389
# std       18.151083    98.491209     18.774465     3.226149     6.722274
# min        4.000000     0.000000     16.000000     0.000000   917.000000
# 25%       18.000000     8.000000     41.000000     0.000000   940.000000
# 50%       36.000000    64.000000     56.000000     0.000000   945.000000
# 75%       54.000000   197.000000     71.000000     0.000000   949.000000
# max       59.000000   359.000000    100.000000    43.800000   965.000000
#
#                 RS            RU          TEMP           VV          BEN  ...  \
# count  4933.000000  16921.000000  18951.000000  6520.000000  6447.000000  ...
# mean    201.490168      0.389161     16.262947     1.348681     0.351823  ...
# ...

# %%
nuevo_df = df[["Datetime","O3", "PM10", "PM25", "CO", "NOX"]]

# %%
nuevo_df
# Out:
#          Datetime     O3  PM10  PM25   CO    NOX
# 0      2019-01-01    NaN   NaN   NaN  0.8  232.0
# 1      2019-01-02    NaN   NaN   NaN  1.0  334.0
# 2      2019-01-03    NaN   NaN   NaN  0.9  269.0
# 3      2019-01-04    NaN   NaN   NaN  1.0  304.0
# 4      2019-01-05    NaN   NaN   NaN  0.9  241.0
# ...           ...    ...   ...   ...  ...    ...
# 21182  2023-07-27  100.0   NaN   NaN  NaN   25.0
# 21183  2023-07-28  100.0   NaN   NaN  NaN   28.0
# 21184  2023-07-29   75.0   NaN   NaN  NaN   21.0
# 21185  2023-07-30   78.0   NaN   NaN  NaN   20.0
# 21186  2023-07-31  101.0   NaN   NaN  NaN   16.0
#
# [21187 rows x 6 columns]

# %%
nuevo_df.describe()
# Out:
#                  O3         PM10         PM25            CO           NOX
# count  15404.000000  9610.000000  6426.000000  10233.000000  21110.000000
# mean      52.558565    18.557648     9.761905      0.315851     46.907011
# std       23.171959    13.927262     6.128935      0.161801     44.143814
# min        1.000000     1.000000     1.000000      0.100000      3.000000
# 25%       35.000000    10.000000     6.000000      0.200000     20.000000
# 50%       54.000000    16.000000     9.000000      0.300000     33.000000
# 75%       70.562500    23.000000    12.000000      0.400000     57.000000
# max      120.000000   432.000000    83.000000      2.000000    501.000000

# %% [markdown]
# ## DIAGRAMAS DE DISPERSIÓN

# %%
columna1 = nuevo_df['PM10']
columna2 = nuevo_df['PM25']

# %%
df_dispersión = pd.DataFrame({'PM10': columna1, 'PM25': columna2})

# %%
df_dispersión.to_csv('dispersión_CALIDAD1.csv', index=False)

# %%
columna1 = nuevo_df['O3']
columna2 = nuevo_df['NOX']

# %%
df_dispersión = pd.DataFrame({'O3': columna1, 'NOX': columna2})

# %%
df_dispersión.to_csv('dispersión_CALIDAD2.csv', index=False)

# %%
columna1 = nuevo_df['O3']
columna2 = nuevo_df['PM10']

# %%
df_dispersión = pd.DataFrame({'O3': columna1, 'PM10': columna2})

# %%
df_dispersión.to_csv('dispersión_CALIDAD3.csv', index=False)

# %%
columna1 = nuevo_df['O3']
columna2 = nuevo_df['PM25']

# %%
df_dispersión = pd.DataFrame({'O3': columna1, 'PM25': columna2})

# %%
df_dispersión.to_csv('dispersión_CALIDAD4.csv', index=False)

# %%
x = nuevo_df.PM10
y = nuevo_df.PM25
plt.xlabel("Variable PM10")
plt.ylabel("Variable PM25")
plt.title("Gráfico de Dispersión")
plt.scatter(x, y)

# %%
x = nuevo_df.O3
y = nuevo_df.NOX
plt.xlabel("Variable O3")
plt.ylabel("Variable NOX")
plt.title("Gráfico de Dispersión")
plt.scatter(x, y)

# %%
C

# %%
x = nuevo_df.PM25
y = nuevo_df.O3
plt.xlabel("Variable PM10")
plt.ylabel("Variable O3")
plt.title("Gráfico de Dispersión")
plt.scatter(x, y)

# %%
x = nuevo_df.NOX
y = nuevo_df.PM10
plt.xlabel("Variable PM10")
plt.ylabel("Variable O3")
plt.title("Gráfico de Dispersión")
plt.scatter(x, y)

# %% [markdown]
# ## SIN

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df.O3, bins=10)
plt.title("Histograma O3")
plt.xlabel("asdada")
plt.xticks(rotation=0)
plt.ylabel("Count")
plt.style.use('ggplot')
plt.show()

# %%
plt.hist(df.PM10, bins=10)
plt.title("Histograma PM10")
plt.xlabel("asdada")
plt.xticks(rotation=0)
plt.ylabel("Count")
plt.style.use('ggplot')
plt.show()

# %%
plt.hist(df.PM25, bins=10)
plt.title("Histograma PM25")
plt.xlabel("asdada")
plt.xticks(rotation=0)
plt.ylabel("Count")
plt.style.use('ggplot')
plt.show()

# %%
plt.hist(df.CO, bins=10)
plt.title("Histograma CO")
plt.xlabel("asdada")
plt.xticks(rotation=0)
plt.ylabel("Count")
plt.style.use('ggplot')
plt.show()

# %%
plt.hist(df.NOX, bins=10)
plt.title("Histograma NOX")
plt.xlabel("asdada")
plt.xticks(rotation=0)
plt.ylabel("Count")
plt.style.use('ggplot')
plt.show()

# %% [markdown]
# # CON

# %%
def fill_na(row, col):
    if math.isnan(row[col]):
        value = df[df['Datetime'] == row['Datetime']][col].mean()
    else:
        value = row[col]
    return value

# %%
def fill_na(row, col):
    if math.isnan(row[col]):
        value = nuevo_df[nuevo_df['Datetime'] == row['Datetime']][col].mean()
    else:
        value = row[col]
    return value

# %%
col_to_fill = 'NOX'
nuevo_df[col_to_fill] = nuevo_df.apply(lambda row: fill_na(row, col_to_fill), axis=1)
# Out:
# /var/folders/2z/t01lgfsd58jchmhphmw9nnrw0000gn/T/ipykernel_6372/3654684852.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nuevo_df[col_to_fill] = nuevo_df.apply(lambda row: fill_na(row, col_to_fill), axis=1)

# %%
col_to_fill = 'CO'
nuevo_df[col_to_fill] = nuevo_df.apply(lambda row: fill_na(row, col_to_fill), axis=1)
# Out:
# /var/folders/2z/t01lgfsd58jchmhphmw9nnrw0000gn/T/ipykernel_6372/3747482618.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nuevo_df[col_to_fill] = nuevo_df.apply(lambda row: fill_na(row, col_to_fill), axis=1)

# %%
col_to_fill = 'PM10'
nuevo_df[col_to_fill] = nuevo_df.apply(lambda row: fill_na(row, col_to_fill), axis=1)
# Out:
# /var/folders/2z/t01lgfsd58jchmhphmw9nnrw0000gn/T/ipykernel_6372/2946469320.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nuevo_df[col_to_fill] = nuevo_df.apply(lambda row: fill_na(row, col_to_fill), axis=1)

# %%
col_to_fill = 'PM25'
nuevo_df[col_to_fill] = nuevo_df.apply(lambda row: fill_na(row, col_to_fill), axis=1)
# Out:
# /var/folders/2z/t01lgfsd58jchmhphmw9nnrw0000gn/T/ipykernel_6372/2848046971.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nuevo_df[col_to_fill] = nuevo_df.apply(lambda row: fill_na(row, col_to_fill), axis=1)

# %%
col_to_fill = 'O3'
nuevo_df[col_to_fill] = nuevo_df.apply(lambda row: fill_na(row, col_to_fill), axis=1)
# Out:
# /var/folders/2z/t01lgfsd58jchmhphmw9nnrw0000gn/T/ipykernel_6372/3031367015.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nuevo_df[col_to_fill] = nuevo_df.apply(lambda row: fill_na(row, col_to_fill), axis=1)

# %%
nuevo_df.describe()
# Out:
#                  O3          PM10          PM25            CO           NOX
# count  21187.000000  21187.000000  21187.000000  21187.000000  21187.000000
# mean      52.758002     18.747336      9.852854      0.315092     46.896168
# std       22.891531     13.295410      5.816517      0.135804     44.091985
# min        1.000000      1.000000      1.000000      0.100000      3.000000
# 25%       35.727778     11.000000      6.000000      0.222222     20.000000
# 50%       54.757778     16.166667      8.750000      0.300000     33.000000
# 75%       70.847143     23.333333     12.500000      0.388889     57.000000
# max      120.000000    432.000000     83.000000      2.000000    501.000000

# %%
plt.hist(df.O3, bins=10)
plt.title("Histograma O3")
plt.xlabel("asdada")
plt.xticks(rotation=0)
plt.ylabel("Count")
plt.style.use('ggplot')
plt.show()

# %%
plt.hist(df.CO, bins=10)
plt.title("Histograma CO")
plt.xlabel("asdada")
plt.xticks(rotation=0)
plt.ylabel("Count")
plt.style.use('ggplot')
plt.show()

# %%
plt.hist(df.CO, bins=10)
plt.title("Histograma CO")
plt.xlabel("asdada")
plt.xticks(rotation=0)
plt.ylabel("Count")
plt.style.use('ggplot')
plt.show()

# %%
plt.hist(df.PM25, bins=10)
plt.title("Histograma PM25")
plt.xlabel("asdada")
plt.xticks(rotation=0)
plt.ylabel("Count")
plt.style.use('ggplot')
plt.show()

# %%
plt.hist(df.PM10, bins=10)
plt.title("Histograma PM10")
plt.xlabel("asdada")
plt.xticks(rotation=0)
plt.ylabel("Count")
plt.style.use('ggplot')
plt.show()
